# %% [markdown]
# # `Практикум по программированию на языке Python`
#
# ## `Задание 01. Полносвязная нейронная сеть на numpy`.
#
# #### Фамилия, имя:  Кривуля Полина
#
# Дата выдачи: <span style="color:red">__28 февраля 17:00__</span>.
#
# Мягкий дедлайн: <span style="color:red">__14 марта 23:59__</span>.
#
# Стоимость: __10 баллов__ (основная часть заданий) + __3 балла__ (дополнительные задания).
#
# <span style="color:red">__В ноутбуке все клетки должны выполняться без ошибок при последовательном их выполнении.__</span>
#
# #### `Москва, 2023`

# %%
import numpy as np

# %% [markdown]
# ## `Теоретическая часть (3 балла)`

# %% [markdown]
# В этом блоке вам нужно решить 3 задания.

# %% [markdown]
# ### `Задание 1. Градиенты для слоя Batch normalization (1.5 балла)`

# %% [markdown]
# Рассмотрим слой Batch normalization. Пусть на вход этого слоя был подан батч из $n$ объектов, при этом у всех объектов по 1 признаку. Представим вход BN слоя в виде $X \in \mathbb{R}^{n \times 1}$.
#
# Тогда в этом слое производятся следующие вычисления:
#
# $$ \mu = \frac1n \sum_{i=1}^{n} X_i $$
#
# $$ \sigma^2 = \frac1n \sum_{i=1}^{n} \left( X_i - \mu \right) ^2 $$
#
# $$ \tilde{y_i} = \frac{X_i - \mu}{\sqrt{\sigma^2 + \varepsilon}} $$
#
# $$ y_i = \gamma \tilde{y_i} + \delta $$
#
# Выходом BN слоя является $y_i$, а $\gamma$ и $\delta$ в нем — параметры, которые подбираются во время обучения вместе с другими параметрами нейронной сети (наряду, например, с весами линейного слоя).
#
# Рассмотрим нейронную сеть, в которой есть BN слой. Предположим, что вычисления в нейронной завершаются подсчетом функции потерь $\mathcal{L}$. Пусть мы выполнили прямой проход по нейронной сети и сейчас делаем обратный проход с помощью метода обратного распространения ошибки. Пусть BN слою пришел градиент функции потерь по выходу BN слоя ($\nabla_{y} \mathcal{L}$).
#
# В этом задании вам нужно записать вычисление градиента функции потерь по параметрам слоя BN $\gamma$ и $\delta$ ($\nabla_{\gamma} \mathcal{L}$, $\nabla_{\delta} \mathcal{L}$) через $\nabla_{y} \mathcal{L}$, а также вам нужно записать вычисление градиента функции потерь по входу слоя BN $X$ ($\nabla_{X} \mathcal{L}$) через $\nabla_{y} \mathcal{L}$.
#
# Хочу заметить, в данном задании мы рассматриваем объекты всего с 1 признаком, чтобы упростить выкладки.

# %% [markdown]
# __Ваше решение:__
#
# __1) ${\nabla}_\gamma \mathcal{L}, {\nabla}_\delta \mathcal{L}$ через ${\nabla}_y \mathcal{L}$__
#
# $\delta, \gamma \in \mathbb{R}$
#
# $y_i = \gamma \tilde{y_i} + \delta$
#
# $\Rightarrow y = \gamma \tilde{y} + \overrightarrow{1} * \delta$
#
# $\Rightarrow dy = \gamma d\tilde{y} + \tilde{y} d \gamma + \overrightarrow{1} * d \delta$
#
# Мы считаем, что нам известен градиент ${\nabla}_y \mathcal{L}$.
#
# $d\mathcal{L} = \langle {\nabla}_y \mathcal{L}, dy \rangle =
# \langle {\nabla}_{y} \mathcal{L}, \gamma d\tilde{y} \rangle + \langle {\nabla}_y \mathcal{L}, \tilde{y} d\gamma \rangle + \langle {\nabla}_{y} \mathcal{L}, \overrightarrow{1} d \delta \rangle =
# \langle \gamma {\nabla}_{y} \mathcal{L}, d\tilde{y} \rangle
# + \langle \tilde{y}^T {\nabla}_y \mathcal{L}, d\gamma \rangle +
# \langle \overrightarrow{1}^T {\nabla}_{y} \mathcal{L}, d \delta \rangle $
#
# $\Rightarrow {\nabla}_\gamma \mathcal{L} = \tilde{y}^T {\nabla}_y \mathcal{L},  $
#
# ${\nabla}_\delta \mathcal{L} = \overrightarrow{1}^T {\nabla}_{y} \mathcal{L} $
#
# ${\nabla}_{\tilde{y}} \mathcal{L} = \gamma {\nabla}_{y} \mathcal{L} $ (понадобится в п.2)
#
# __2) $\nabla_{X} \mathcal{L}$ через $\nabla_{y} \mathcal{L}$__
#
# $\tilde{y_i} = \frac{X_i - \mu}{\sqrt{\sigma^2 + \varepsilon}} \Rightarrow \tilde{y} = \frac{X - \overrightarrow{1}* \mu}{\sqrt{\sigma^2 + \varepsilon}} $;
#
# $$d\tilde{y} = \frac{d(X - \mu \cdot \overrightarrow{1}) \sqrt{\delta^2 + \varepsilon} - (X - \mu \cdot \overrightarrow{1}) d\sqrt{\delta^2 + \varepsilon}}{\delta^2 + \varepsilon} = \frac{(dX - \overrightarrow{1} d\mu) \sqrt{\delta^2 + \varepsilon} - (X - \mu \cdot \overrightarrow{1})\frac{d(\delta^2 + \varepsilon)}{2\sqrt{\delta^2 + \varepsilon}}}{\delta^2 + \varepsilon} = $$
# = {подставим формулы $\mu$ и $\delta$} = $$ = \frac{(dX - \overrightarrow{1} d\frac{\sum{X_i}}{n}) \sqrt{\delta^2 + \varepsilon} - (X - \mu \cdot \overrightarrow{1})\frac{d \frac{\sum (X_i - \mu)^2}{n}}{2\sqrt{\delta^2 + \varepsilon}}}{\delta^2 + \varepsilon} = \frac{(dX - \overrightarrow{1} d\frac{\overrightarrow{1} ^ TX}{n}) \sqrt{\delta^2 + \varepsilon} - (X - \mu \cdot \overrightarrow{1})\frac{d \frac{< (X_i - \mu\cdot\overrightarrow{1}), (X_i - \mu\cdot\overrightarrow{1})>}{n}}{2\sqrt{\delta^2 + \varepsilon}}}{\delta^2 + \varepsilon} =$$ $$= \frac{(dX - \frac{\overrightarrow{1}\overrightarrow{1} ^ T}{n} d{X}) \sqrt{\delta^2 + \varepsilon} - \frac{(X - \mu \cdot \overrightarrow{1})}{n\sqrt{\delta^2 + \varepsilon} }{< (X_i - \mu\cdot\overrightarrow{1}), d(X_i - \mu\cdot\overrightarrow{1})>}}{\delta^2 + \varepsilon}=$$
#
# $$ = \frac{(dX - \frac{\overrightarrow{1}\overrightarrow{1} ^ T}{n} d{X}) \sqrt{\delta^2 + \varepsilon} - \frac{(X - \mu \cdot \overrightarrow{1})}{n\sqrt{\delta^2 + \varepsilon} }{< (X_i - \mu\cdot\overrightarrow{1}), (I_n-\frac{{\overrightarrow{1}}{\overrightarrow{1}^T}}{n})dX)>}}{\delta^2 + \varepsilon} = $$
#
# $$ \frac{(dX - \frac{\overrightarrow{1}\overrightarrow{1} ^ T}{n} d{X}) \sqrt{\delta^2 + \varepsilon} - \frac{(X - \mu \cdot \overrightarrow{1})}{n\sqrt{\delta^2 + \varepsilon} }{(X_i - \mu\cdot\overrightarrow{1})^T (I_n-\frac{{\overrightarrow{1}}{\overrightarrow{1}^T}}{n})dX)}}{\delta^2 + \varepsilon} = $$
#
# $$=\frac{(I_n - \frac{\overrightarrow{1}\overrightarrow{1} ^ T}{n}) d{X}} {\sqrt{\delta^2 + \varepsilon}} - \frac{(X - \mu \cdot \overrightarrow{1}) (X_i - \mu\cdot\overrightarrow{1})^T (I_n-\frac{{\overrightarrow{1}}{\overrightarrow{1}^T}}{n})dX}{n(\delta^2 + \varepsilon)^{3/2}} = $$
#
# $$=(\frac{(I_n - \frac{\overrightarrow{1}\overrightarrow{1} ^ T}{n})} {\sqrt{\delta^2 + \varepsilon}} - \frac{(X - \mu \cdot \overrightarrow{1}) (X_i - \mu\cdot\overrightarrow{1})^T (I_n-\frac{{\overrightarrow{1}}{\overrightarrow{1}^T}}{n})}{n(\delta^2 + \varepsilon)^{3/2}})dX$$
#
# $$\Rightarrow \nabla_{X} \mathcal{\tilde{y}} ^ T = \frac{(I_n - \frac{\overrightarrow{1}\overrightarrow{1} ^ T}{n})} {\sqrt{\delta^2 + \varepsilon}} - \frac{(X - \mu \cdot \overrightarrow{1}) (X_i - \mu\cdot\overrightarrow{1})^T (I_n-\frac{{\overrightarrow{1}}{\overrightarrow{1}^T}}{n})}{n(\delta^2 + \varepsilon)^{3/2}}$$
#
# $$\nabla_{X} \mathcal{L} = {\nabla}_{\tilde{y}} \mathcal{L} \nabla_{X} \mathcal{\tilde{y}}  = \gamma {\nabla}_{y} \mathcal{L} * (\frac{(I_n - \frac{\overrightarrow{1}\overrightarrow{1} ^ T}{n})} {\sqrt{\delta^2 + \varepsilon}} - \frac{(I_n-\frac{{\overrightarrow{1}}{\overrightarrow{1}^T}}{n}) (X - \mu \cdot \overrightarrow{1}) (X_i - \mu\cdot\overrightarrow{1})^T}{n(\delta^2 + \varepsilon)^{3/2}}) $$

# %% [markdown]
# ### `Задание 2. Вывод инициализации весов линейного слоя при использовании ReLU в качестве функции активации (1 балл)`

# %% [markdown]
# Рассмотрим полносвязную нейронную сеть с функцией активации $g(y)$. Пусть сеть состоит из $L$ слоев и размер входа слоя $l$ равен $n_l\ \ (l = \overline{1, L})$.
#
# Обозначим за $x^l \in \mathbb{R}^{n_{l}}$ вход слоя $l$, за $y^l \in \mathbb{R}^{n_{l+1}}$ — выход слоя $l$, за $W^l \in \mathbb{R}^{n_{l+1} \times n_{l}}$ — веса слоя $l$, за $b^l \in \mathbb{R}^{n_{l+1}}$ — вектор сдвига слоя $l$.
#
# Тогда
# $$y^l = W^l x^l + b^l,$$
# $$x^{l+1} = g(y^l).$$
#
# На паре вы выводили хорошую инициализацию для линейного слоя в случае, когда в качестве функции активации $g(y)$ в нейронной сети используется гиперболический тангенс $g(y) = \tanh(y)$. Сейчас вам нужно сделать подобный вывод для случая, когда в сети в качестве функций активации используется $g(y) = ReLU(y) = \max(0, y)$.
#
# Сделаем следующие предположения насчет того, как распределены веса $W^l$, вектор сдвига $b^l$, входной вектор $x^l$, выходной вектор $y^l$ линейного слоя и градиенты функции потерь $\frac{\partial L}{\partial y^{l}}$ $(l = \overline{1, L}$):
#
# 1. Все компоненты в $W^l$ распределены одинаково и независимо друг от друга;
# 2. Все компоненты в $y^l$ распределены одинаково и независимо друг от друга;
# 3. Все компоненты в $x^l$ распределены одинаково и независимо друг от друга;
# 4. Все компоненты в $\frac{\partial L}{\partial y^{l}}$ распределены одинаково и независимо друг от друга;
# 5. Все компоненты в $W^l$ и все компоненты в $x^l$ независимы друг от друга;
# 6. Все компоненты в $W^l$ имеют четную плотность распределения (то есть симметричную относительно нуля: $p_{W^l}(-x) = p_{W^l}(x)$);
# 7. Все компоненты в $W^l$ имеют конечное матожидание;
# 8. Вектор $b^l$ инициализирован нулями.
#
#
# Подсказки:
# 1. Из пунктов 6 и 7 следует, что все компоненты в $W^l$ имеют нулевое среднее ($\mathbb{E} W^l_{ij} = 0\ \ \forall i = \overline{1, n_{l+1}}, j = \overline{1, n_{l}}$) (докажите);
# 2. Из пунктов 6 и 7 следует, что все компоненты в $y^l$ имеют нулевое среднее и четную плотность распределения (докажите).
#
# (добавили) Условия на независимость градиентов:
#
# 1. $dL/dx^{l} ⫫ dx^{l}/dy^{l-1}$
# 2. $dL/dy^{l} ⫫ dy^{l}/dx^{l}$

# %% [markdown]
# __Ваше решение:__
#
# $$ g(y) = ReLU(y) = \max(0, y) $$
#
# $$p_{y^l_i}(-y_i)=\sum p_W(-W)p_x(x)=\sum p_W(W)p_x(x)=p_{y^l_i}(-y_i)$$
#
# 1) Рассмотрим прямой проход по сети
#
# На прямом проходе мы хотим добиться того, чтобы математическое ожидание и дисперсия активаций оставались неизменными от слоя к слою.
#
# $$y^l = W^lx^l+b^l \Rightarrow ^{(8) } Ey^l_i=E\sum_{j=1}^{n^l}W^l_{ij}x^l_j$$
# $$W^l_{ij} = g(W^l_{ij})-g(-W^l_{ij})$$
# $$EW^l_{ij} = Eg(W^l_{ij})-Eg(-W^l_{ij})=(6)= \int_{0}^{+\infty} W^l_{ij} p(W^l_{ij})dx - \int_{-\infty}^0(-W^l_{ij})p(W^l_{ij})dx =(6)=0$$
# $$\Rightarrow(1,3)\Rightarrow Ey_i^l=0$$
# $$Dy^l_i=D\sum_{j=1}^{n^l}W^l_{ij}x^l_j = \sum_{j=1}^{n^l}DW^l_{ij}x^l_j=(1), (3) =
# \sum_{j=1}^{n^l}(DW^l_{ij}Dx^l_j+(EW^l_{ij})^2Dx^l_j+DW^l_{ij}(Ex^l_j)^2) =
# \sum_{j=1}^{n^l}(DW^l_{ij}Dx^l_j+DW^l_{ij}(Ex^l_j)^2)=(Dx=Ex^2-(Ex)^2)=\sum_{j=1}^{n^l}DW^l_{ij}E(x^l_j)^2=
# n^lDW^lE(x^l)^2$$
# $$\Rightarrow Dy^l_i=n^lDW^lE(x^l)^2$$
# $$p_{y^l_i}(-y_i)=\sum p_W(-W)p_x(x)=\sum p_W(W)p_x(x)=p_{y^l_i}(-y_i)$$
# Так как $x^l=g(y^{l-1})$,  нужно найти $E(g(y^{l-1}))^2$.
# $$E(g(y^{l-1}))^2=E((y^{l-1})^2|y^{l-1}>0)P(y^{l-1}>0)=(p(y^{l-1}){~}четно)=\frac{1}{2}E(y^{l-1})^2$$
# $$\Rightarrow Dy^l_i=\frac{1}{2}n^lDW^lE(y^{l-1})^2$$
# Так как дисперсия активаций неизменна от слоя к слою,
# $$Dy^l=Dy^{l-1}=\frac{1}{2}n^lDW^lE(y^{l-1})^2$$
# $$E(y^{l-1})^2=Dy^{l-1}+(Ey^{l-1})^2=Dy^{l-1}$$
# $$Dy^{l-1}=\frac{1}{2}n^lDW^lDy^{l-1}$$
# $$\Rightarrow DW^l=\frac{2}{n^l}$$
#
#
#
# 2) Рассмотрим обратный проход
#
# На обратном проходе мы хотим добиться того, чтобы мат.ожидание и дисперсия градиентов оставались неизменными от слоя к слою.
#
# $$\delta_j^{l-1}=\frac{\partial \mathcal{L}}{\partial y^{l-1}_j}=I[y^l_j>0]\sum_{i=1}^{n^{l+1}}W^l_{ij}\frac{\partial \mathcal{L}}{\partial y^{l}_i}$$
#
# $$E\delta_j^{l-1}=P(y^l_j>0)\sum_{i=1}^{n^{l+1}}EW^l_{ij}E\delta_j^{l-1}=0$$
# $$D\delta_j^{l-1}=D(I[y^l_j>0]\sum_{i=1}^{n^{l+1}}W^l_{ij}\delta_j^{l-1}) = $$
#
# $$ = D(I[y^l_j>0])D(\sum_{i=1}^{n^{l+1}}W^l_{ij}\delta_j^{l-1})+(E(I[y^l_j>0]))^2 D(\sum_{i=1}^{n^{l+1}}W^l_{ij}\delta_j^{l-1})+D(I[y^l_j>0])(E(\sum_{i=1}^{n^{l+1}}W^l_{ij}\delta_j^{l-1}))^2$$
#
# $$E(I[y^l_j>0]) = \frac{1}{2}$$
# $$D(I[y^l_j>0]) = E(I[y^l_j>0])^2-(E(I[y^l_j>0]))^2=\frac{1}{4}$$
# $$D\delta_j^{l-1}=\frac{1}{2}D(\sum_{i=1}^{n^{l+1}}W^l_{ij}\delta_j^{l-1})=\frac{1}{2}\sum_{i=1}^{n^{l+1}}D(W^l_{ij}\delta_j^{l-1})=\sum_{j=1}^{n^{l+1}}(DW^l_{ij}D\delta_j^{l-1}+(EW^l_{ij})^2D\delta_j^{l-1}+DW^l_{ij}(E\delta_j^{l-1})^2)=\frac{n^{l+1}}{2}DW^l_{ij}D\delta_j^{l-1}$$
# $$D\delta_j^{l}=D\delta_j^{l-1} \Rightarrow DW^l=\frac{2}{n^{l+1}}$$
#
# Имеем: $DW^l=\frac{2}{n^l}=\frac{2}{n^{l+1}}, EW^l=0$

# %% [markdown]
# ### `Задание 3. Почему функция активации` $ReLU(y) = \max(0, y)$ `предпочтительней сигмоиды` $\sigma(y) = \frac{1}{1 + \exp(-y)}$ `в нейронных сетях? (0.5 балла)`

# %% [markdown]
# Дайте развернутый ответ на вопрос "Почему функция активации $ReLU(y) = \max(0, y)$ предпочтительней сигмоиды $\sigma(y) = \frac{1}{1 + \exp(-y)}$ в нейронных сетях?"

# %% [markdown]
# __Ваш ответ:__
#
# При использовании сигмоиды возникает проблема затухания градиентов, так как ее производная при насыщенном сигнале близка к нулю. Также вычислительно затратно вычислять экспоненту, исспользующуюся в сигмоиде и ее производной. У ReLU(y) производная равна 1 при y>0 и 0 при y<0, проблема затухания градиентов отстутствует, а также ReLU быстро вычисляется.

# %% [markdown]
# ---

# %% [markdown]
# ## `Практическая часть (7 баллов)`

# %% [markdown]
# ### `Реализация нейронной сети (3 балла)`

# %% [markdown]
# В этом задании вы обучите полносвязную нейронную сеть распознавать рукописные цифры (а что же еще, если не их :), [почти] самостоятельно реализовав все составляющие алгоритма обучения и предсказания.
#
# Для начала нам понадобится реализовать прямой и обратный проход через слои. Наши слои будут соответствовать следующему интерфейсу (на примере "тождественного" слоя):

# %%
class IdentityLayer:
    """
    A building block. Each layer is capable of performing two things:

    - Process input to get output:           
    output = layer.forward(input)

    - Propagate gradients through itself:    
    grad_input = layer.backward(input, grad_output)

    Some layers also have learnable parameters.

    Modified code from cs.hse DL course *
    """
    def __init__(self):
        """
        Here you can initialize layer parameters (if any) 
        and auxiliary stuff. You should enumerate all parameters
        in self.params
        """
        # An identity layer does nothing
        self.params = []
        pass

    def forward(self, input):
        """
        Takes input data of shape [batch, input_units], 
        returns output data [batch, output_units]
        """
        # An identity layer just returns whatever it gets as input.
        self.input = input
        return input

    def backward(self, grad_output): 
        """
        Performs a backpropagation step through the layer, 
        with respect to the given input.

        To compute loss gradients w.r.t input, 
        you need to apply chain rule (backprop):

        d `loss` / d `input` = (d `loss` / d `layer`) * (d `layer` / d `input`)

        Luckily, you already receive d `loss` / d `layer` in argument, 
        so you only need to multiply it by d `layer` / d `input`.

        NB: Sometimes d `layer` / d `input` can be a 3D or even 4D tensor.
        So it's better to write down the `loss` differential and extract
        d `layer` / d `input` from it so that only 2D tensors were present.

        The method returns:
        * gradient w.r.t input (will be passed to 
          previous layer's backward method)
        * flattened gradient w.r.t. parameters (with .ravel() 
          applied to each gradient). 
          If there are no params, return []
        """
        """
        grad_output = d `loss` / d `layer`
        нужно посчитать d `layer` / d `input`
        """
        # The gradient of an identity layer is precisely grad_output
        input_dim = self.input.shape[1]

        d_layer_d_input = np.eye(input_dim)

        return np.dot(grad_output, d_layer_d_input), [] # chain rule

# %% [markdown]
# #### `Слой нелинейности ReLU`

# %% [markdown]
# Для начала реализуем слой нелинейности $ReLU(y) = \max(0, y)$. Параметров у слоя нет. Метод `forward` должен вернуть результат поэлементного применения $ReLU$ к входному массиву, метод `backward` — градиент функции потерь по входу слоя. В нуле будем считать производную равной 0. Обратите внимание, что при обратном проходе могут понадобиться величины, посчитанные во время прямого прохода, поэтому их стоит сохранить как атрибут класса.

# %%
class ReLU:
    """
    Modified code from cs.hse DL course *
    """
    def __init__(self):
        """ReLU layer simply applies elementwise rectified linear unit to all inputs"""
        self.params = [] # ReLU has no parameters

    def forward(self, input):
        """Apply elementwise ReLU to [batch, num_units] matrix"""
        ### your code here
        self.input = input
        self.output = input * (input > 0)
        return self.output
        
    def backward(self, grad_output):
        """Compute gradient of loss w.r.t. ReLU input
        grad_output shape: [batch, num_units]
        output 1 shape: [batch, num_units]
        output 2: []
        """
        ### your code here 
        """
        dz / dx = [x > 0]
        """
        return grad_output * (self.input > 0), []
    
    def __repr__(self):
        return 'Relu()'

# %% [markdown]
# #### `Полносвязный слой`

# %% [markdown]
# Далее реализуем полносвязный слой без нелинейности. У слоя два параметра: матрица весов и вектор сдвига.
#
# Обратите внимание на второй аргумент: в нем надо возвращать градиент по всем параметрам в одномерном виде. Для этого надо сначала применить `.ravel()` ко всем градиентам, а затем воспользоваться `np.r_`:

# %%
# example
np.r_[np.eye(3).ravel(), np.arange(4)]
# Out:
# array([1., 0., 0., 0., 1., 0., 0., 0., 1., 0., 1., 2., 3.])

# %%
class Dense:
    """
    Modified code from cs.hse DL course *
    """
    def __init__(self, input_units, output_units):
        """
        A dense layer is a layer which performs a learned affine transformation:
        f(x) = x W + b
        """
        # initialize weights with small random numbers from normal distribution
        self.weights = np.random.randn(input_units, output_units) * 0.01
        self.biases = np.zeros(output_units)
        self.params = [self.weights, self.biases]

    def forward(self,input):
        """
        Perform an affine transformation:
        f(x) = x W + b
        
        input shape: [batch, input_units]
        output shape: [batch, output units]
        """
        ### your code here
        self.input = input
        self.output = np.dot(input, self.weights) + self.biases
        return self.output

    def backward(self, grad_output):
        """
        compute gradients
        grad_output shape: [batch, output_units]
        output shapes: [batch, input_units], [num_params]
        
        hint: use function np.r_
        np.r_[np.arange(3), np.arange(3)] = [0, 1, 2, 0, 1, 2]
        """
        ### your code here
        # dL = (dL/dz)^T dz = (dL/dz)^T (x dW + dx w + db)
        '''
        dL_dw = np.dot(grad_output.T, self.input)
        dL_dx = np.dot(grad_output, self.weights.T)
        dL_db = np.dot(grad_output, np.ones((len(self.biases), 1)))
        '''
        dL_dw = np.dot(self.input.T, grad_output)
        dL_dx = np.dot(grad_output, self.weights.T)
        dL_db = np.dot(grad_output.T, np.ones((grad_output.shape[0], 1)))
        return dL_dx, np.r_[dL_dw.ravel(), dL_db.ravel()]
    
    def __repr__(self):
        return f'Dense({self.weights.shape[0]}, {self.weights.shape[1]})'

# %% [markdown]
# #### `Проверка градиента`

# %% [markdown]
# Проверим правильность реализации с помощью функции численной проверки градиента. Функция `eval_numerical_gradient` принимает на вход callable объект `f` (функцию от одного аргумента-матрицы) и аргумент `x` и вычисляет приближенный градиент функции `f` в точке `x`.

# %%
def eval_numerical_gradient(f, x, verbose=False, h=0.00001):
    """
    Evaluates gradient df/dx via finite differences:
    df/dx ~ (f(x+h) - f(x-h)) / 2h
    Adopted from https://github.com/ddtm/dl-course/
    """
    fx = f(x) # evaluate function value at original point
    grad = np.zeros_like(x)
    # iterate over all indexes in x
    it = np.nditer(x, flags=['multi_index'], op_flags=['readwrite'])
    while not it.finished:

        # evaluate function at x+h
        ix = it.multi_index
        oldval = x[ix]
        x[ix] = oldval + h # increment by h
        fxph = f(x) # evalute f(x + h)
        x[ix] = oldval - h
        fxmh = f(x) # evaluate f(x - h)
        x[ix] = oldval # restore

        # compute the partial derivative with centered formula
        grad[ix] = (fxph - fxmh) / (2 * h) # the slope
        if verbose:
            print (ix, grad[ix])
        it.iternext() # step to next dimension

    return grad

# %% [markdown]
# Вычислите аналитический и численный градиенты по входу слоя ReLU от функции
# $$ f(y) = \sum_i y_i, \quad y = ReLU(x) $$
#
# Выпишите аналитический градиент в этой ячейке:
#
# $${\nabla}_x f = {\nabla}_y f {\nabla}_x y = {\nabla}_y f I[x>0]=I[x>0]$$

# %% [markdown]
# Следующая ячейка после заполнения должна не выдавать ошибку :)

# %%
relu = ReLU()
points = np.linspace(-1, 1, 10*12).reshape([10, 12])

### your code here
### grads = 
### numeric_grads = 
x = relu.forward(points)
grad_y = np.ones(x.shape)
grads = relu.backward(grad_y)[0]

numeric_grads = eval_numerical_gradient(lambda x: (x * (x > 0)).sum(), points)

assert np.allclose(grads, numeric_grads, rtol=1e-3, atol=0)

# %% [markdown]
# Вычислите аналитический и численный градиенты по входу полносвязного слоя от функции
# $$ f(y) = \sum_i y_i, \quad y = W x + b $$
#
# Выпишите аналитический градиент в этой ячейке (советуем выписать градиент через дифференциал функции $f$):
#
# Обозначим за E вектор из единиц размерности, соответствующей y. То есть такой, чтобы выполнялось $ f(y) = E^T y $. Тогда
#
# $$df = E^Tdy=E^Td(Wx+b)=E^T(dW*x+Wdx+db)$$
# $$\Rightarrow {\nabla}_x f = (E^TW)^T=W^TE$$

# %% [markdown]
# Следующая ячейка после заполнения должна не выдавать ошибку :)

# %%
linear = Dense(12, 32)
points = np.linspace(-1, 1, 10*12).reshape([10, 12])

### your code here
### grads = 
### numeric_grads = 
numeric_grads = eval_numerical_gradient(lambda x: (np.dot(x, linear.weights)).sum(), points)

x = linear.forward(points)
grad_y = np.ones(x.shape)
grads = linear.backward(grad_y)[0]

assert np.allclose(grads, numeric_grads, rtol=1e-3, atol=0)

# %% [markdown]
# #### `Реализация softmax-слоя и функции потерь`

# %% [markdown]
# Для решения задачи многоклассовой классификации обычно используют $softmax$ в качестве нелинейности на последнем слое, чтобы получить вероятности классов для каждого объекта:
# $$\hat y = softmax(x)  = \left \{\frac {\exp(x^i)}{\sum_{j=1}^K \exp(x^j)} \right \}_{i=1}^K, \quad K - \text{число классов.}$$
#
# Здесь за $x^i$ мы обозначаем $i$-ый признак объекта $x$.
#
# В качестве функции потерь выберем отрицательный логарифм правдоподобия (по английски: negative log likelihood или NLL)
# $$L(y, \hat y) = -\sum_{i=1}^K y^i \log \hat y^i,$$
# где $y^i = 1$, если объект принадлежит $i$-му классу, и $y^i = 0$ иначе.
#
# NLL совпадает с выражением для [кросс-энтропии](https://ru.wikipedia.org/wiki/Перекрёстная_энтропия) (в качестве первого распределения берем вырожденное распределение $y$, в качестве второго — предсказанное распределение $\hat y$). Очевидно, что эту функцию потерь также можно переписать через индексацию, если через $y$ обозначить класс данного объекта:
# $$L(y, \hat y) = - \log \hat y_{y}$$
#
# В таком виде ее удобно реализовывать.

# %% [markdown]
# Для обучения нейронной сети будем оптимизировать эту функцию потерь по параметрам нейронной сети:
#
# $$ \frac1N \sum_{i=1}^N L(y_i, \hat y_i) = \frac1N \sum_{i=1}^N L(y_i, \text{NN}(x_i)) \rightarrow \min_{w}\,,$$
# где за $x_i$ и $y_i$ мы обозначили признаки и таргет $i$-ого объекта обучающей выборки, за $\text{NN}$ мы обозначили нейронную сеть, которая по признакам объекта $x_i$ выдает распределение вероятностей $\hat y_i$, за $w$ мы обозначили все веса нейронной сети, а $N$ — это число объектов в обучающей выборке.

# %% [markdown]
# Реализуйте слой `LogSoftmax` (у этого слоя нет параметров). Метод `forward` должен вычислять логарифм от $softmax$, а метод `backward` — пропускать градиенты. В общем случае в промежуточных вычислениях `backward` получится трехмерный тензор, однако для нашей конкретной функции потерь все вычисления можно реализовать в матричном виде.  Поэтому мы будем предполагать, что аргумент `grad_output` — это матрица, у которой в каждой строке только одно ненулевое значение (не обязательно единица).

# %%
from scipy.special import logsumexp
# use this function instead of np.log(np.sum(np.exp(...))) because it is more stable

# %%
class LogSoftmax:
    def __init__(self):
        self.params = []

    def forward(self, input):
        """
        Applies softmax to each row and then applies component-wise log
        Input shape: [batch, num_units]
        Output shape: [batch, num_units]
        """
        ### your code here
        self.input = input
        self.output = input - logsumexp(input, axis=1)[:, np.newaxis]
        return self.output
        
    def backward(self, grad_output):
        """
        Propagartes gradients.
        Assumes that each row of grad_output contains only 1 
        non-zero element
        Input shape: [batch, num_units]
        Output shape: [batch, num_units]
        Do not forget to return [] as second value (grad w.r.t. params)
        """
        ### your code here
        return grad_output - grad_output.sum(axis=1)[:, np.newaxis] * np.exp(self.output), []
    
    def __repr__(self):
        return 'LogSoftmax()'

# %% [markdown]
# Реализуйте функцию потерь и градиенты функции потерь. Во время вычисления NLL усредняйте (а не суммируйте) значения функции потерь по батчу. Обычно так делают для того, чтобы при двух запусках обучения нейронной сети с разными размерами батча получаемые значения функции потерь у этих сетей были сравнимы.

# %%
def NLL(activations, target):
    """
    Returns negative log-likelihood of target under model represented by
    activations (log probabilities of classes, it's just output of LogSoftmax layer).
    `activations` has shape [batch, num_classes], `target` has shape [batch]
    Output shape: 1 (scalar).
    """
    ### your code here
    rng = list(range(target.shape[0])) # строки 0...len(target)
    return 0 - np.mean(activations[rng, target])


def grad_NLL(activations, target):
    """
    Returns gradient of negative log-likelihood w.r.t. activations.
    each arg has shape [batch, num_classes]
    output shape: [batch, num-classes]
    """
    ### your code here
    rng = list(range(target.shape[0])) # строки 0...len(target)
    grad = np.zeros_like(activations)
    grad[rng, target] -= 1 / len(target)
    return grad

# %% [markdown]
# Наконец, выполните проверку `LogSoftmax`-слоя, используя функцию потерь и ее градиент:

# %%
lsm = LogSoftmax()
target = np.arange(10)
points = np.linspace(-1, 1, 10 * 12).reshape([10, 12])

### your code here
### grads = 
### numeric_grads = 

x = lsm.forward(points)
grad_output = grad_NLL(x, target)
grads = lsm.backward(grad_output)[0]
numeric_grads = eval_numerical_gradient(lambda x: NLL(lsm.forward(x), target), points)

assert np.allclose(grads, numeric_grads, rtol=1e-3, atol=0)

# %% [markdown]
# ### `Загрузка данных`

# %% [markdown]
# Мы реализаовали все архитектурные составляющие нашей нейронной сети. Осталось загрузить данные и обучить модель. Мы будем работать с датасетом `digits`, каждый объект в котором — это 8x8 изображение рукописной цифры.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import load_digits

# %%
X, y = load_digits(return_X_y=True)

# %%
X.shape, y.shape
# Out:
# ((1797, 64), (1797,))

# %% [markdown]
# Разделим данные на обучение и контроль:

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
X_train.shape, X_test.shape
# Out:
# ((1347, 64), (450, 64))

# %% [markdown]
# ### `Сборка и обучение нейронной сети (1 балл)`

# %% [markdown]
# В нашей реализации мы представляем нейронную сеть в виде списка ее слоев. Например, следующая функция конструирует нейронную сеть заданной ширины (то есть с заданным размером скрытых слоев) и глубины (то есть с заданным количеством слоев) с заданным размером входа и выхода, а также с заданной функцией активации между линейными слоями.

# %%
def make_network(input_size, hidden_layers_size, output_size, n_layers=3, activation_class=ReLU):
    network = []

    for layer_idx in range(n_layers):
        # Compute sizes of current linear layer
        layer_in = input_size if layer_idx == 0 else hidden_layers_size
        layer_out = output_size if layer_idx == n_layers - 1 else hidden_layers_size
        
        # Add linear layer to the network
        network.append(Dense(layer_in, layer_out))

        # Add activation after each layer except the last one
        if layer_idx != n_layers - 1:
            network.append(activation_class())

    # Add LogSoftmax layer to the network
    network.append(LogSoftmax())

    return network

# %%
input_size = X_train.shape[1]
hidden_layers_size = 32
output_size = 10

network = make_network(input_size, hidden_layers_size, output_size, 3, ReLU)
network
# Out:
# [Dense(64, 32), Relu(), Dense(32, 32), Relu(), Dense(32, 10), LogSoftmax()]

# %% [markdown]
# Реализуйте функцию, которая выполнет прямой проход по нейронной сети:

# %%
def forward(network, X):
    """
    Perform forward pass through the network.
    
    network: list of layers
    X: raw data
    X shape: [batch, features_num]

    output: 
    output shape: [batch, out_features_num]
    """
    ### your code here
    X_new = X
    for i in network:
        X_new = i.forward(X_new)
    return X_new

# %% [markdown]
# Для проверки, хорошо ли сеть обучилась, нам понадобится вычислять долю правильных ответов (accuracy) на данной выборке. Для этого реализуйте функцию, которая делает предсказания на каждом объекте (логично в качестве предсказания на очередном объекте выдавать тот класс, для которого предсказанный логарифм вероятности максимален):

# %%
def predict(network, X):
    """
    Returns predictions for each object in X.
    
    network: list of layers
    X: raw data
    X shape: [batch, features_num]

    output: array of classes, each from 0 to 9
    output shape: [batch]
    """
    ### your code here
    X_new = forward(network, X)
    pred = np.argmax(X_new, axis=1)
    return pred

# %% [markdown]
# Мы будем обучать параметры нейросети с помощью готовой функции оптимизации из модуля `scipy`:

# %%
from scipy.optimize import minimize

# %%
help(minimize)
# Out:
# Help on function minimize in module scipy.optimize._minimize:
#
# minimize(fun, x0, args=(), method=None, jac=None, hess=None, hessp=None, bounds=None, constraints=(), tol=None, callback=None, options=None)
#     Minimization of scalar function of one or more variables.
#
#     Parameters
#     ----------
#     fun : callable
#         The objective function to be minimized.
#
#             ``fun(x, *args) -> float``
#
#         where ``x`` is an 1-D array with shape (n,) and ``args``
#         is a tuple of the fixed parameters needed to completely
#         specify the function.
#     x0 : ndarray, shape (n,)
#         Initial guess. Array of real elements of size (n,),
#         where 'n' is the number of independent variables.
#     args : tuple, optional
#         Extra arguments passed to the objective function and its
#         derivatives (`fun`, `jac` and `hess` functions).
#     method : str or callable, optional
#         Type of solver.  Should be one of
#
# ...

# %% [markdown]
# Эта функция имеет стандартный интерфейс: нужно передать callable объект, который вычисляет значение и градиент целевой функции, а также точку старта оптимизации — начальное приближение (одномерный `numpy`-массив). Поэтому нам понадобятся функции для сбора и задания всех весов нашей нейросети (именно для них мы всегда записывали параметры слоя в список `layer.params`)

# %%
def get_weights(network):
    weights = []
    for layer in network:
        for param in layer.params:
            weights += param.ravel().tolist()
    return np.array(weights)


def set_weights(weights, network):
    i = 0
    for layer in network:
        for param in layer.params:
            l = param.size
            param[:] = weights[i:i+l].reshape(param.shape)
            i += l

# %% [markdown]
# Вам нужно реализовать ту самую функцию, которую мы будем передавать в `minimize`. Эта функция должна брать на вход текущую точку (вектор всех параметров), а также список дополнительных параметров (мы будем передавать через них нашу сеть и обучающие данные) и возвращать значение критерия качества (NLL) и его градиент по параметрам модели.

# %%
def compute_loss_grad(weights, args):
    """
    takes current weights and computes cross-entropy and gradients
    weights shape: [num_parameters]
    output 1: loss (scalar)
    output 2: gradint w.r.t. weights, shape: [num_parameters]
    
    hint: firstly perform forward pass through the whole network
    then compute loss and its gradients
    then perform backward pass, transmitting first baskward output
    to the previos layer and saving second baskward output in a list
    finally flatten all the gradients in this list
    (in the order from the first to the last layer)
    
    Do not forget to set weights of the network!
    """
    network, X, y = args
    ### your code here
    # Do not forget to set weights of the network!
    set_weights(weights, network)
    # сначала сделать forward
    X_new = forward(network, X) 
    # посчитать loss
    loss = NLL(X_new, y)
    # посчитать градиенты 
    gradients = grad_NLL(X_new, y)
    # затем выполните обратный проход, 
    # передав первый обратный вывод на предыдущий слой и сохранив второй обратный вывод в списке
    list_parametrs = []
    for layer in network[::-1]: # проход обратный
        gradients, parameters = layer.backward(gradients)
        list_parametrs.append(parameters)
    return loss, np.concatenate(list_parametrs[::-1])

# %% [markdown]
# Теперь мы готовы обучать нашу нейросеть.

# %%
weights = get_weights(network)

# %%
res = minimize(
    compute_loss_grad, weights,       # fun and start point
    args=[network, X_train, y_train], # args passed to fun
    method="L-BFGS-B",                # optimization method
    jac=True                          # says that gradient is computed in fun
)

# %%
res.keys()
# Out:
# dict_keys(['fun', 'jac', 'nfev', 'njev', 'nit', 'status', 'message', 'x', 'success', 'hess_inv'])

# %%
res["nit"] # number of iterations (should be >> 10)
# Out:
# 114

# %%
res["success"] # should be True
# Out:
# True

# %%
res["x"] # leraned weights
# Out:
# array([-0.00917377,  0.0080283 , -0.0077286 , ..., -0.05361006,
#        -1.22653567, -0.24060183])

# %% [markdown]
# Выведите качество на обучении (`X_train`, `y_train`) и на контроле (`X_test`, `y_test`). Не забудьте установить веса!

# %%
### your code here
pred_train = predict(network, X_train)
pred_test = predict(network, X_test)
print("TRAIN:", np.mean(pred_train == y_train))
print("TEST:", np.mean(pred_test == y_test))
# Out:
# TRAIN: 1.0
# TEST: 0.9555555555555556

# %% [markdown]
# У `minimize` есть также аргумент `callback` — в нее можно передать функцию, которая будет вызываться после каждой итерации оптимизации. Такую функцию удобно оформить в виде метода класса, который будет сохранять качество на обучении контроле после каждой итерации. Реализуйте этот метод в классе `Callback`:

# %%
class Callback:
    def __init__(self, network, X_train, y_train, X_test, y_test, print=False):
        self.network = network
        self.X_train = X_train
        self.X_test = X_test
        self.y_train = y_train
        self.y_test = y_test
        self.print = print
        self.train_acc = []
        self.test_acc = []
        
    def call(self, weights):
        """
        Computes quality on train and test set with given weights
        and saves to self.train_acc and self.test_acc.
        If self.print is True, also prints these 2 values
        """
        ### your code here
        pred_train = predict(network, X_train)
        pred_test = predict(network, X_test)
        self.train_acc.append(np.mean(pred_train == y_train))
        self.test_acc.append(np.mean(pred_test == y_test))
        if self.print:
            print(len(self.train_acc), "TRAIN:", self.train_acc[-1], "TEST:", self.test_acc[-1])

# %%
cb = Callback(network, X_train, y_train, X_test, y_test, print=True)

res = minimize(
    compute_loss_grad, weights,  
    args=[network, X_train, y_train], 
    method="L-BFGS-B",
    jac=True,
    callback=cb.call
)
# Out:
# 1 TRAIN: 0.10616184112843356 TEST: 0.08444444444444445
# 2 TRAIN: 0.10319227913882702 TEST: 0.09555555555555556
# 3 TRAIN: 0.10319227913882702 TEST: 0.09555555555555556
# 4 TRAIN: 0.170007423904974 TEST: 0.15777777777777777
# 5 TRAIN: 0.17297698589458055 TEST: 0.14888888888888888
# 6 TRAIN: 0.23311061618411286 TEST: 0.2288888888888889
# 7 TRAIN: 0.33778767631774315 TEST: 0.3377777777777778
# 8 TRAIN: 0.30957683741648107 TEST: 0.32666666666666666
# 9 TRAIN: 0.3682256867112101 TEST: 0.3888888888888889
# 10 TRAIN: 0.4357832219747587 TEST: 0.4222222222222222
# 11 TRAIN: 0.5189309576837416 TEST: 0.5044444444444445
# 12 TRAIN: 0.5478841870824054 TEST: 0.5266666666666666
# 13 TRAIN: 0.6651818856718634 TEST: 0.6355555555555555
# 14 TRAIN: 0.7015590200445434 TEST: 0.6666666666666666
# 15 TRAIN: 0.7260579064587973 TEST: 0.6866666666666666
# 16 TRAIN: 0.7357089829250185 TEST: 0.7044444444444444
# 17 TRAIN: 0.7750556792873051 TEST: 0.7311111111111112
# ...

# %% [markdown]
# Изобразите на графике кривую качества на обучени и контроле по итерациям:

# %%
# %pylab inline
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

#отображение графиков в ноутбуке
# %matplotlib inline 

#для четкой прорисовки графиков
# %config InlineBackend.figure_format = 'svg'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
ax.plot(cb.train_acc, label="train acc")
ax.plot(cb.test_acc, label="test acc")
ax.set_xlabel("Iteration")
ax.set_ylabel("Accuracy")
ax.grid(True)
ax.legend()

fig.tight_layout()
plt.show()

# %% [markdown]
# ### `Эксперименты с числом слоев (1 балл)`

# %% [markdown]
# Ясно, что из-за случайного начального приближения с каждым запуском обучения мы будем получать различное качество. Попробуем обучить нашу нейросеть с разным числом слоев несколько раз.
#
# Заполните матрицы `accs_train` и `accs_test`. В позиции `[i, j]` должна стоять величина доли правильных ответов сети с $i+1$ полносвязными слоями при $j$-м запуске (все запуски идентичны).

# %%
accs_train = np.zeros((5, 5))
accs_test = np.zeros((5, 5))

# %%
### your code here
for i in range(0, accs_train.shape[0]):
    for j in range(0, accs_train.shape[1]):
        network = make_network(input_size, hidden_layers_size, output_size, i + 1, ReLU)
        cb = Callback(network, X_train, y_train, X_test, y_test, print=False)
        res = minimize(
            compute_loss_grad, get_weights(network),  
            args=[network, X_train, y_train], 
            method="L-BFGS-B",
            jac=True,
            callback=cb.call
        )
        accs_train[i, j] = cb.train_acc[-1]
        accs_test[i, j] = cb.test_acc[-1]

# %% [markdown]
# Построим боксплоты полученного качества (горизонтальная линия в каждом столбце — среднее, прямоугольник показывает разброс).

# %%
fig, axes = plt.subplots(2, 1, figsize=(10, 8))

axes[0].boxplot(accs_train.T, showfliers=False)
axes[1].boxplot(accs_test.T, showfliers=False)

axes[0].set_xlabel("Number of layers")
axes[1].set_xlabel("Number of layers")

axes[0].set_ylabel("Train accuracy")
axes[1].set_ylabel("Test accuracy")

axes[0].set_title("Train quality in 5 runs")
axes[1].set_title("Test quality in 5 runs")

axes[0].grid(True)
axes[1].grid(True)

fig.tight_layout()
plt.show()

# %% [markdown]
# Дайте развёрнутый ответ на вопросы (в этой же ячейке):
# * Как изменяются качество на обучении и контроле и устойчивость процесса обучения при увеличении числа слоев?
# * Можно ли сказать, что логистическая регрессия (линейная модель) дает качество хуже, чем нелинейная модель?
#
# __Ответы:__
#
# 1. На обучении вне зависимости от числа слоев и номера запуска качество абсолютное. Эксперимент с числом слоев был запущен несколько раз и было замечено, что с увеличением числа слоев разброс увеличивается, то есть качество на тесте становится менее устойчивым.
#
# 2. Можно ли сказать, что логистическая регрессия (линейная модель) дает качество хуже, чем нелинейная модель? На запуске, который изображен выше, это действительно так (по сравнению с 2 и 3 слоями), но при некоторых запусках данная модель давала качество, сопоставимое с 2 и 3 слоями (даже, бывало, что у них качество немного хуже). При этом линейная модель имеет наименьший разброс. Поэтому про то, что она дает качество хуже, сказать нельзя.

# %% [markdown]
# ### `Эксперименты c различными инициализациями весов (1 балл)`

# %% [markdown]
# Как уже было сказано, начальная инициализация весов нейронной сети может сильно влиять на процесс ее обучения и, как следствие, на ее качество.
#
# В этом пункте вам предлагается попробовать обучить несколько нейронных сетей с различными инициализациями слоев.
#
# Для этого необходимо реализовать функцию, инициализирующую веса линейных слоёв нашей нейронной сети. Добавьте в функционал данного метода возможность инициализировать его веса с помощью инициализации Kaiming (используется, если в нейронной сети в качестве функций активации используется ReLU) и инициализации Xavier (используется, если в нейронной сети в качестве функций активации используется Tanh или Sigmoid):

# %%
def initialize_network(network, initialization):
    for layer in network:
        if isinstance(layer, Dense):
            input_units, output_units = layer.weights.shape
            if initialization == 'Kaiming': # ReLU
                ### your code here
                layer.weights = np.random.normal(scale=np.sqrt(2 / input_units), size=(input_units, output_units))
                pass
            elif initialization == 'Xavier': # Tanh или Sigmoid
                ### your code here
                a = np.sqrt(6 / (input_units + output_units))
                layer.weights = np.random.uniform(-a, a,
                                                  size=(input_units, output_units))
                pass
            else:
                # Initialize weights with small random numbers from normal distribution.
                # In this case `initialization` represents a standard deviation
                # for normal distribution.
                layer.weights = np.random.randn(input_units, output_units) * initialization
            layer.biases = np.zeros_like(layer.biases)
            
            layer.params = [layer.weights, layer.biases]

# %% [markdown]
# Теперь попробуйте для каждой из 3 инициализаций обучить нейронную сеть несколько раз. Попробуйте проделать данную операцию при зафиксированном числе слоев равным 3, 4 и 5.

# %% [markdown]
# #### `3 слоя`
#
# Зафиксируйте в сети число слоев равное трем.

# %% [markdown]
# Заполните матрицы `accs_train` и `accs_test`. В позиции `[i, j]` должна стоять величина доли правильных ответов сети при $j$-м запуске (все запуски идентичны) с инициализацией Kaiming при $i = 3$, с инициализацией Xavier при $i = 4$ и с инициализацией из нормального распределения с фиксированными параметрами при $0 \leqslant i \leqslant 2$ (попробуйте здесь 3 разных параметра для стандартного отклонения для нормального распределения, например: `1e-3`, `1e-2`, `1e-1`). Заметьте, что при большом числе слоев слишком низкое стандартное отклонение может не давать нейронной сети нормально обучиться.

# %%
init_vars = [1e-3, 1e-2, 1e-1, 'Kaiming', 'Xavier']

# %%
accs_train = np.zeros((5, 5))
accs_test = np.zeros((5, 5))

# %%
### your code here
for i, elems in enumerate(init_vars):
    for j in range(0, accs_train.shape[1]):
        network = make_network(input_size, hidden_layers_size, output_size, 3, ReLU)
        initialize_network(network, elems)
        cb = Callback(network, X_train, y_train, X_test, y_test, print=False)
        res = minimize(
            compute_loss_grad, get_weights(network),  
            args=[network, X_train, y_train], 
            method="L-BFGS-B",
            jac=True,
            callback=cb.call
        )
        accs_train[i, j] = cb.train_acc[-1]
        accs_test[i, j] = cb.test_acc[-1]

# %% [markdown]
# Построим боксплоты полученного качества (горизонтальная линия в каждом столбце — среднее, прямоугольник показывает разброс).

# %% [markdown]
# Изначально в графике строился только тест, в вопросах же спрашивают и про трейн, поэтому вот

# %%
'''
init_vars_for_plot = [(x if isinstance(x, str) else fr"$\sigma = {x}$") for x in init_vars]

fig, ax = plt.subplots(1, 1, figsize=(10, 5))

ax.boxplot(accs_test.T, labels=init_vars_for_plot, showfliers=False)

ax.set_title("Test quality in 5 runs")
ax.set_xlabel("Initialization")
ax.set_ylabel("Test accuracy")
ax.grid(True)

fig.tight_layout()
plt.show()
'''
init_vars_for_plot = [(x if isinstance(x, str) else fr"$\sigma = {x}$") for x in init_vars]

fig, axes = plt.subplots(2, 1, figsize=(10, 8))

axes[0].boxplot(accs_train.T, labels=init_vars_for_plot, showfliers=False)
axes[1].boxplot(accs_test.T, labels=init_vars_for_plot, showfliers=False)

axes[0].set_xlabel("Number of layers")
axes[1].set_xlabel("Number of layers")

axes[0].set_ylabel("Train accuracy")
axes[1].set_ylabel("Test accuracy")

axes[0].set_title("Train quality in 5 runs")
axes[1].set_title("Test quality in 5 runs")

axes[0].grid(True)
axes[1].grid(True)

fig.tight_layout()
plt.show()

# %% [markdown]
# #### `4 слоя`
#
# Выполните тут тот же код, что и в предыдущем пункте, но только уже с 4 слоями в сети.

# %%
init_vars = [5e-3, 1e-2, 1e-1, 'Kaiming', 'Xavier']

# %%
accs_train = np.zeros((5, 5))
accs_test = np.zeros((5, 5))

# %%
### your code here
for i, elems in enumerate(init_vars):
    for j in range(0, accs_train.shape[1]):
        network = make_network(input_size, hidden_layers_size, output_size, 4, ReLU)
        initialize_network(network, elems)
        cb = Callback(network, X_train, y_train, X_test, y_test, print=False)
        res = minimize(
            compute_loss_grad, get_weights(network),  
            args=[network, X_train, y_train], 
            method="L-BFGS-B",
            jac=True,
            callback=cb.call
        )
        accs_train[i, j] = cb.train_acc[-1]
        accs_test[i, j] = cb.test_acc[-1]

# %% [markdown]
# Построим боксплоты полученного качества (горизонтальная линия в каждом столбце — среднее, прямоугольник показывает разброс).

# %%
'''
init_vars_for_plot = [(x if isinstance(x, str) else fr"$\sigma = {x}$") for x in init_vars]

fig, ax = plt.subplots(1, 1, figsize=(10, 5))

ax.boxplot(accs_test.T, labels=init_vars_for_plot, showfliers=False)

ax.set_title("Test quality in 5 runs")
ax.set_xlabel("Initialization")
ax.set_ylabel("Test accuracy")
ax.grid(True)

fig.tight_layout()
plt.show()
'''
init_vars_for_plot = [(x if isinstance(x, str) else fr"$\sigma = {x}$") for x in init_vars]

fig, axes = plt.subplots(2, 1, figsize=(10, 8))

axes[0].boxplot(accs_train.T, labels=init_vars_for_plot, showfliers=False)
axes[1].boxplot(accs_test.T, labels=init_vars_for_plot, showfliers=False)

axes[0].set_xlabel("Number of layers")
axes[1].set_xlabel("Number of layers")

axes[0].set_ylabel("Train accuracy")
axes[1].set_ylabel("Test accuracy")

axes[0].set_title("Train quality in 5 runs")
axes[1].set_title("Test quality in 5 runs")

axes[0].grid(True)
axes[1].grid(True)

fig.tight_layout()
plt.show()

# %% [markdown]
# #### `5 слоев`
#
# Выполните тут тот же код, что и в предыдущем пункте, но только уже с 5 слоями в сети.

# %%
init_vars = [1e-2, 1e-1, 1e0, 'Kaiming', 'Xavier']

# %%
accs_train = np.zeros((5, 5))
accs_test = np.zeros((5, 5))

# %%
### your code here
for i, elems in enumerate(init_vars):
    for j in range(0, accs_train.shape[1]):
        network = make_network(input_size, hidden_layers_size, output_size, 5, ReLU)
        initialize_network(network, elems)
        cb = Callback(network, X_train, y_train, X_test, y_test, print=False)
        res = minimize(
            compute_loss_grad, get_weights(network),  
            args=[network, X_train, y_train], 
            method="L-BFGS-B",
            jac=True,
            callback=cb.call
        )
        accs_train[i, j] = cb.train_acc[-1]
        accs_test[i, j] = cb.test_acc[-1]

# %% [markdown]
# Построим боксплоты полученного качества (горизонтальная линия в каждом столбце — среднее, прямоугольник показывает разброс).

# %%
'''
init_vars_for_plot = [(x if isinstance(x, str) else fr"$\sigma = {x}$") for x in init_vars]

fig, ax = plt.subplots(1, 1, figsize=(10, 5))

ax.boxplot(accs_test.T, labels=init_vars_for_plot, showfliers=False)

ax.set_title("Test quality in 5 runs")
ax.set_xlabel("Initialization")
ax.set_ylabel("Test accuracy")
ax.grid(True)

fig.tight_layout()
plt.show()
'''
init_vars_for_plot = [(x if isinstance(x, str) else fr"$\sigma = {x}$") for x in init_vars]

fig, axes = plt.subplots(2, 1, figsize=(10, 8))

axes[0].boxplot(accs_train.T, labels=init_vars_for_plot, showfliers=False)
axes[1].boxplot(accs_test.T, labels=init_vars_for_plot, showfliers=False)

axes[0].set_xlabel("Number of layers")
axes[1].set_xlabel("Number of layers")

axes[0].set_ylabel("Train accuracy")
axes[1].set_ylabel("Test accuracy")

axes[0].set_title("Train quality in 5 runs")
axes[1].set_title("Test quality in 5 runs")

axes[0].grid(True)
axes[1].grid(True)

fig.tight_layout()
plt.show()

# %% [markdown]
# Дайте развёрнутый ответ на вопросы (в этой же ячейке):
# * Как отличаются качество на обучении и контроле и устойчивость процесса обучения при различных инициализациях?
# * Какие инициализации помогают обучать более глубокие сети?
#
# __Ответы:__
# 1. Качество на обучении всегда, кроме $\sigma = {1.0}$ и 5 слоев, равно 1. Случай $\sigma = {1.0}$ и 5 слоев уникальный, судя по качеству и на тесте, и на трейне, НС просто нормально не обучилась. Kaiming и Xavier дают в целом лучше качество, у Xavier разброс сравнимый с другими инициализациями (кроме упомянутого выше случая), а у Kaiming в целом меньший разброс.
# 2. Инициализация Kaiming помогает обучать более глубокие сети за счет стабильного поведения и лучшего качества

# %% [markdown]
# Теперь сравним скорость обучения при различных инициализациях. Создайте два списка списков `accs_test_on_iterations`, `accs_train_on_iterations` в каждом из которых в позиции `[i]` (см. описание `i` в предыдущем пункте) будет лежать список из значений `accuracy` на тестовой и обучающей выборках соотвественно, полученных во время обучения модели. Количество слоев в сети зафиксируйте равным 4.

# %%
init_vars = [1e-3, 1e-2, 1e-1, 'Kaiming', 'Xavier']

# %%
accs_test_on_iterations = []
accs_train_on_iterations = []

# %%
### your code here
for i, elems in enumerate(init_vars):
    network = make_network(input_size, hidden_layers_size, output_size, 4, ReLU)
    initialize_network(network, elems)
    cb = Callback(network, X_train, y_train, X_test, y_test, print=False)
    res = minimize(
        compute_loss_grad, get_weights(network),  
        args=[network, X_train, y_train], 
        method="L-BFGS-B",
        jac=True,
        callback=cb.call
    )
    accs_train_on_iterations.append(cb.train_acc)
    accs_test_on_iterations.append(cb.test_acc)

# %%
init_vars_for_plot = [(x if isinstance(x, str) else fr"$\sigma = {x}$") for x in init_vars]

fig, ax = plt.subplots(2, 1, figsize=(10, 8))

for idx, label in enumerate(init_vars_for_plot):
    ax[0].plot(accs_train_on_iterations[idx], label=label)

ax[0].set_title("Train quality for different initializations")
ax[0].set_xlabel("Epoch number")
ax[0].set_ylabel("Train accuracy")
ax[0].grid(True)
ax[0].legend()

for idx, label in enumerate(init_vars_for_plot):
    ax[1].plot(accs_test_on_iterations[idx], label=label)

ax[1].set_title("Test quality for different initializations")
ax[1].set_xlabel("Epoch number")
ax[1].set_ylabel("Test accuracy")
ax[1].grid(True)
ax[1].legend()

fig.tight_layout()
plt.show()

# %% [markdown]
# Дайте развёрнутый ответ на вопросы (в этой же ячейке):
# * Как меняется скорость обучения в зависимости от выбранной инициализации?
#
# __Ответы:__
#
# Сначала казалось, что $\sigma$=0.001 отсутствует на графике, но оно есть, просто маленькая синяя черточка в самом низу. Наблюдаем, что с уменьшением $\sigma$ ухудшается сходимость: "при большом числе слоев слишком низкое стандартное отклонение может не давать нейронной сети нормально обучиться". При этом самая быстрая сходимость наблюдается для самого $\sigma$=0.1 и Kaiming, Xavier

# %% [markdown]
# ### `Эксперименты c различными функциями активации (1 балл)`

# %% [markdown]
# Проверим теперь, с какой функцией активации нейронная сеть будет обучаться лучше.
#
# В этом пункте вам предлагается попробовать обучить несколько нейронных сетей с различными функциями активации.
#
# Для этого нам нужно реализовать еще 2 слоя: для функций активации `Tanh` и `Sigmoid`.

# %%
class Tanh:
    """
    tanh(y) = (e^y - e^(-y)) / (e^y + e^(-y))
    Используйте функцию np.tanh для подсчета гиперболического тангенса.
    Вы можете сами реализовать подсчет tanh, но тогда вам нужно устойчиво его вычислять.
    """
    def __init__(self):
        self.params = [] # Tanh has no parameters

    def forward(self, input):
        """
        Apply elementwise Tanh to [batch, num_units] matrix
        """
        ### your code here
        self.input = input
        self.output = np.tanh(input)
        return self.output

    def backward(self, grad_output):
        """
        Compute gradient of loss w.r.t. Tanh input
        grad_output shape: [batch, num_units]
        output 1 shape: [batch, num_units]
        output 2: []
        """
        ### your code here
        # return grad_output / (np.cosh(self.input) ** 2), []
        return grad_output * (1 - np.tanh(self.input) ** 2), []

    def __repr__(self):
        return 'Tanh()'

# %%
from scipy.special import expit
    
class Sigmoid:
    """
    sigmoid(y) = 1 / (1 + e^(-y))
    Используйте функцию expit для подсчета сигмоиды.
    Вы можете сами реализовать подсчет сигмоиды, но тогда вам нужно устойчиво ее вычислять.
    """
    def __init__(self):
        self.params = [] # Sigmoid has no parameters

    def forward(self, input):
        """
        Apply elementwise Sigmoid to [batch, num_units] matrix
        """
        ### your code here
        self.input = input
        self.output = expit(input)
        return self.output

    def backward(self, grad_output):
        """
        Compute gradient of loss w.r.t. Sigmoid input
        grad_output shape: [batch, num_units]
        output 1 shape: [batch, num_units]
        output 2: []
        """
        ### your code here
        return grad_output * self.output * (1 - self.output), []

    def __repr__(self):
        return 'Sigmoid()'

# %% [markdown]
# Теперь попробуйте для каждой из 3 функций активации обучить нейронную сеть несколько раз. Число слоев зафиксируйте равным 3. В случае `Tanh` и `Sigmoid` используйте инициализацию `Xavier`, а в случае `ReLU` используйте инициализацию `Kaiming`.

# %% [markdown]
# Заполните матрицы `accs_train` и `accs_test`. В позиции `[i, j]` должна стоять величина доли правильных ответов сети при $j$-м запуске (все запуски идентичны) с функцией активации $ReLU$ при $i = 0$, с функцией активации $Tanh$ при $i = 1$ и с функцией активации $Sigmoid$ при $i = 2$.

# %%
act_func_vars = ['Tanh', 'Sigmoid', 'ReLU']
init_for_act_funcs = ['Xavier', 'Xavier', 'Kaiming']

# %%
accs_train = np.zeros((3, 5))
accs_test = np.zeros((3, 5))

# %% [markdown]
# В описании задания идет измененный порядок функций в матрицах, я надеюсь, это не принципиально и оставляю как в инициализации соответствующих переменных

# %%
### your code here
act_func_vars = [Tanh, Sigmoid, ReLU]
for i, elems in enumerate(act_func_vars):
    for j in range(0, accs_train.shape[1]):
        network = make_network(input_size, hidden_layers_size, output_size, 3, act_func_vars[i])
        initialize_network(network, init_for_act_funcs[i])
        cb = Callback(network, X_train, y_train, X_test, y_test, print=False)
        res = minimize(
            compute_loss_grad, get_weights(network),  
            args=[network, X_train, y_train], 
            method="L-BFGS-B",
            jac=True,
            callback=cb.call
        )
        accs_train[i, j] = cb.train_acc[-1]
        accs_test[i, j] = cb.test_acc[-1]
act_func_vars = ['Tanh', 'Sigmoid', 'ReLU']

# %% [markdown]
# Построим боксплоты полученного качества (горизонтальная линия в каждом столбце — среднее, прямоугольник показывает разброс).

# %%
fig, ax = plt.subplots(2, 1, figsize=(10, 8))

ax[0].boxplot(accs_train.T, labels=act_func_vars, showfliers=False)
ax[0].set_title("Train quality in 5 runs")
ax[0].set_xlabel("Activation function")
ax[0].set_ylabel("Test accuracy")
ax[0].grid(True)

ax[1].boxplot(accs_test.T, labels=act_func_vars, showfliers=False)

ax[1].set_title("Test quality in 5 runs")
ax[1].set_xlabel("Activation function")
ax[1].set_ylabel("Test accuracy")
ax[1].grid(True)

fig.tight_layout()
plt.show()

# %% [markdown]
# Дайте развёрнутый ответ на вопросы (в этой же ячейке):
# * Как отличаются качество на обучении и контроле и устойчивость процесса обучения при различных функциях активации?
#
# __Ответы:__
#
# У сигмоиды, в зависимости от запуска, иногда идет разброс в трейне (в отличие от других функций), но очень небольшой, качество очень близко к 1. На тесте максимальный разброс у тангенса, минимальный разброс и минимальное качество у сигмоиды. Заметно лучшее качество у ReLU.

# %% [markdown]
# \* Несколько фрагментов кода в задании написаны на основе материалов [курса по глубинному обучению на ФКН НИУ ВШЭ](https://www.hse.ru/ba/ami/courses/205504078.html)

# %% [markdown]
# ## `Бонусная часть`

# %% [markdown]
# ### `Реализация метода оптимизации (1 балл)`
#
# Реализуйте сами метод оптимизации (аналог функции `minimize`) для рассмотренной выше архитектуры. В качестве метода оптимизации используйте SGD + momentum. Продемонстрируйте правильную работу метода оптимизации, сравните его работу с LBFGS-B. Сделайте выводы.

# %% [markdown]
# ### `Dropout (1 балл)`
#
# Реализуйте слой Dropout. Сравните обучение сети из большого числа слоёв при использовании Dropout и без его использования (предварительно подберите адекватный параметр $p$). Сделайте выводы.

# %%
class Dropout:
    def __init__(self, p=0.5):
        self.params = []
        self.p = p
        self.inference = False

    def forward(self, input):
        if self.inference:
            return input * (1 - self.p)
        self.m = np.random.geometric(p, input.shape)
        return input * self.m
        
    def backward(self, grad_output):
        return self.m * grad_output, []
    
    def __repr__(self):
        return 'Dropout()'

# %%
class Callback_dropout:
    def __init__(self, network, X_train, y_train, X_test, y_test, print=False):
        self.network = network
        self.X_train = X_train
        self.y_train = y_train
        self.X_test = X_test
        self.y_test = y_test
        self.train_acc = []
        self.test_acc = []
        self.print = print

    def call(self, weights):
        for layer in self.network:
            layer.inference = True
        pred_train = predict(network, X_train)
        pred_test = predict(network, X_test)
        self.train_acc.append(np.mean(pred_train == y_train))
        self.test_acc.append(np.mean(pred_test == y_test))
        for layer in self.network:
            layer.inference = False
        if self.print:
            print(len(self.train_acc), "TRAIN:", self.train_acc[-1], "TEST:", self.test_acc[-1])

# %%
def make_network_dropout(input_size, hidden_layers_size, output_size, n_layers=3, p=0.5, activation_class=ReLU):
    network = []

    for layer_idx in range(n_layers):
        # Compute sizes of current linear layer
        layer_in = input_size if layer_idx == 0 else hidden_layers_size
        layer_out = output_size if layer_idx == n_layers - 1 else hidden_layers_size
        
        # Add linear layer to the network
        network.append(Dense(layer_in, layer_out))

        # Add activation after each layer except the last one
        if layer_idx != n_layers - 1:
            network.append(activation_class())
            network.append(Dropout(p=p))

    # Add LogSoftmax layer to the network
    network.append(LogSoftmax())

    return network

# %%
network = make_network(input_size, hidden_layers_size, output_size, 5, ReLU)
initialize_network(network, 'Kaiming')
cb = Callback(network, X_train, y_train, X_test, y_test, print=False)
res = minimize(
    compute_loss_grad, get_weights(network),  
    args=[network, X_train, y_train], 
    method="L-BFGS-B",
    jac=True,
    callback=cb.call
)
test_acc = cb.test_acc
train_acc = cb.train_acc

# %%
np.arange(0.05, 0.25, 0.04)
# Out:
# array([0.05, 0.09, 0.13, 0.17, 0.21])

# %%
test_acc_dropout = []
train_acc_dropout = []
lst = np.arange(0.05, 0.25, 0.04)
for i in lst:
    network = make_network_dropout(input_size, hidden_layers_size, output_size, 5, i, ReLU)
    initialize_network(network, 'Kaiming')
    cb = Callback_dropout(network, X_train, y_train, X_test, y_test, print=False)
    res = minimize(
        compute_loss_grad, get_weights(network),  
        args=[network, X_train, y_train], 
        method="L-BFGS-B",
        jac=True,
        callback=cb.call
    )
    test_acc_dropout.append(cb.test_acc)
    train_acc_dropout.append(cb.train_acc)

# %%
lst
# Out:
# array([0.05, 0.09, 0.13, 0.17, 0.21])

# %%
def toFixed(numObj, digits=0):
    return f"{numObj:.{digits}f}"

# %%
fig, ax = plt.subplots(2, 1, figsize=(10, 8))

ax[0].plot(train_acc, label="Без Dropout")
i = 0
for idx in lst:
    ax[0].plot(train_acc_dropout[i], label=toFixed(idx,3))
    i += 1

ax[0].set_title("Train quality for different initializations")
ax[0].set_xlabel("Epoch number")
ax[0].set_ylabel("Train accuracy")
ax[0].grid(True)
ax[0].legend()

ax[1].plot(test_acc, label="Без Dropout")
i = 0
for idx in lst:
    ax[1].plot(test_acc_dropout[i], label=toFixed(idx,3))
    i += 1

ax[1].set_title("Test quality for different initializations")
ax[1].set_xlabel("Epoch number")
ax[1].set_ylabel("Test accuracy")
ax[1].grid(True)
ax[1].legend()

fig.tight_layout()
plt.show()

# %% [markdown]
# __Вывод__: при использовании Dropout модель обучается за меньшее число итераций, менее заметно переобучение (если так можно сказать...), качество при хорошем параметре p сравнимо или превосходит (на тесте) качество без использования Dropout.

# %% [markdown]
# ### `BatchNormalization (1 балл)`
#
# Реализуйте слой `BatchNormalization`. Сравните обучение сети из большого числа слоёв при использовании `BatchNormalization` и без его использования. Сделайте выводы.
